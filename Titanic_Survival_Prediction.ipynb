# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer # Handling missing values
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('./Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.drop('Cabin' ,axis=1 ,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex'] = df['Sex'].map({'male':1 ,'female':0})

# %%
df = pd.get_dummies(df,columns=['Embarked'],drop_first=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(['Name','Ticket','PassengerId'],axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example with a specific palette (you can customize the colors)
sns.barplot(x='Sex', y='Survived', data=df, palette=['blue',''])  # You can also try 'Blues', 'coolwarm', etc.
plt.show()
# Out:
# /var/folders/br/sct0z3r90clc3n7k4_qcb5zh0000gn/T/ipykernel_22353/1741186666.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=df, palette='Set2')  # You can also try 'Blues', 'coolwarm', etc.

# %%
sns.barplot(x='Pclass', y='Survived', data=df, palette=['blue', 'orange', 'green'])  # Example with 3 custom colors
plt.show()
# Out:
# /var/folders/br/sct0z3r90clc3n7k4_qcb5zh0000gn/T/ipykernel_22353/2758174914.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=df, palette=['blue', 'orange', 'green'])  # Example with 3 custom colors

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['Survived'] == 1]['Age'],bins=30,color='green',label='Survived',kde=False)
sns.histplot(df[df['Survived'] == 0]['Age'],bins=30,color='red',label='Not Survived',kde=False)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

x = df.drop('Survived',axis=1)
y = df['Survived']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix ,classification_report

lr = LogisticRegression()
lr.fit(x_train, y_train)

# Make predictions and evaluate
y_pred_lr = lr.predict(x_test)
print('Logistic Regression Accuracy:', accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.7988826815642458
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
dt = DecisionTreeClassifier(max_depth=5,random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

print('Decision Tree Accuracy:', accuracy_score(y_test,y_pred))
# Out:
# Decision Tree Accuracy: 0.7988826815642458

# %%
print('confusion matrix(logistic regression):\n',confusion_matrix(y_test,y_pred_lr))
# Out:
# confusion matrix(logistic regression):
#  [[89 16]
#  [20 54]]

# %%
print('confusion matrix(decision tree):\n',confusion_matrix(y_test,y_pred))
# Out:
# confusion matrix(decision tree):
#  [[95 10]
#  [26 48]]

# %%
print('classification report(logistic regression):\n',classification_report(y_test,y_pred_lr))
# Out:
# classification report(logistic regression):
#                precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       105
#            1       0.77      0.73      0.75        74
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
print('classification report(decision tree):\n',classification_report(y_test,y_pred))
# Out:
# classification report(decision tree):
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       105
#            1       0.83      0.65      0.73        74
#
#     accuracy                           0.80       179
#    macro avg       0.81      0.78      0.78       179
# weighted avg       0.80      0.80      0.79       179

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': [3, 5, 7, 10], 'min_samples_split': [2, 5, 10]}
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
grid_search.fit(x_train, y_train)
print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'max_depth': 3, 'min_samples_split': 2}

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_lr)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
